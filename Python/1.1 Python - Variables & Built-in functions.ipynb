# %%
count = 5
type(count)
# Out:
# int

# %%
greeting = "Hello World"
type(greeting)
# Out:
# str

# %%
price = 2.5
type(price)
# Out:
# float

# %%
color_palette = ["mintcream", "burlywood", "salmon"]
type(color_palette)
# Out:
# list

# %%
colors = ("mintcream", "burlywood", "salmon")
type(colors)
# Out:
# tuple

# %%
person_info = {"name": "Jules César", "Job": "Musician", "age": 55}
type(person_info)
# Out:
# dict

# %%
is_active = True
type(is_active)
# Out:
# bool

# %%
#convertir un objet en un autre type d'objet

# %%
count = 5
type(float(count))
# Out:
# float

# %%
price = 5.4
type(int(price))
# Out:
# int

# %%
price = 5.6
type(int(price))
# Out:
# int

# %%
#Que pouvez-vous remarquer ?
#On doit modifier l'objet de la variable en repartant de cette dernière et lui affectant le nouvel objet en amont
#la fonction type permet de nommer l'objet d'une variable mais également de modifier l'objet d'une variable à un autre

# %%
temperature = 5.6
#trouver le moyen d'arrondir temperature
#il faut passer la variable float en int
round(temperature) # ou round(5.6)
# Out:
# 8

# %%
#Après avoir arrondi temperature, est-ce que c'est toujours un float ?
#non il devient un int

# %%
height = 6.0
#non, c'est un float

# %%
#Arrondissez pi avec 3 valeurs décimales.
pi = 3.14159265359
round(3.14159265359,3)
# Out:
# 3.142

# %%
#Utilisez une built-in function pour compter le nombre de caractères dans l'objet de type string suivant:
greeting = "Hello World"
print(len(greeting))
# Out:
# 11

# %%
#Utilisez une built-in function pour compter le nombre d'éléments dans l'objet de type list suivant:
mixed_data = ["non", "pas", 1, "ni", 2, "ni", 3, "mais", 7.2132]
nb_elements = len(mixed_data)
print(nb_elements)
# Out:
# 9

# %%
#Utilisez une built-in function sur une des deux variables pour que resultat contienne une valeur positive
positive_number = 4
negative_number = -5

resultat = positive_number + negative_number
positive_number = abs(4-5)
print(positive_number)


# autre façon d'utiliser la fonction abs
# positive_number = 4
# negative_number = -5

# resultat = abs(positive_number + negative_number)
# print(resultat)
# Out:
# 1

# %%
#Utilisez une built-in function pour renvoyer la valeur minimum de la list suivante
values = [3.2, 41, 2, 23, 7]
min_value = min(values)
print(min_value)
# Out:
# 2

# %%
#Utilisez une built-in function pour renvoyer la somme des valeurs de la list suivante:
values = [3.2, 41, 2, 23, 7]
sum_value = sum(values)
print(sum_value)
# Out:
# 76.2
